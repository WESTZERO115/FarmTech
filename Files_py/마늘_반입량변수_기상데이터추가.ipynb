# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_nanji = pd.read_csv("/Users/parkseoyoung/Desktop/aipSources/살려줘_난지.csv",  encoding='cp949')
df_nanji.head()
# Out:
#        거래일자  저장형 난지 1.0 kg 상자 /특  저장형 난지 1.0 kg 상자 /상  저장형 난지 1.0 kg 상자 /중  \
# 0  2011.1.1                    0                 2692                    0
# 1  2011.2.1                 2761                    0                    0
# 2  2011.3.1                    0                 2662                    0
# 3  2011.4.1                    0                 2665                    0
# 4  2011.5.1                    0                    0                    0
#
#    햇마늘 난지 1.0 kg 상자 /특  햇마늘 난지 1.0 kg 상자 /상  햇마늘 난지 1.0 kg 상자 /하
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                 2820                    0
# 3                    0                 2784                    0
# 4                    0                 1853                    0

# %%
df_nanji = df_nanji.mean(axis=1)
df_nanji
# Out:
# 0      448.666667
# 1      460.166667
# 2      913.666667
# 3      908.166667
# 4      308.833333
#           ...
# 116    983.000000
# 117    987.500000
# 118    985.333333
# 119    984.666667
# 120    986.500000
# Length: 121, dtype: float64

# %%
df_nanji.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df_hanji = pd.read_csv("/Users/parkseoyoung/Desktop/aipSources/살려줘_한지.csv",  encoding='cp949')
df_hanji.head()
# Out:
#        거래일자  저장형 한지 1.0 kg 상자 /특  저장형 한지 1.0 kg 상자 /상  저장형 한지 1.0 kg 상자 /중  \
# 0  2011.1.1                 4800                 4200                    0
# 1  2011.2.1                 4251                    0                    0
# 2  2011.3.1                 4375                    0                    0
# 3  2011.4.1                 5646                    0                    0
# 4  2011.5.1                 4727                    0                    0
#
#    저장형 한지 1.0 kg 상자 /하  햇마늘 한지 1.0 kg 상자 /특  햇마늘 한지 1.0 kg 상자 /하
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0

# %%
df_hanji = df_hanji.mean(axis=1)
df_hanji
# Out:
# 0      1500.000000
# 1       708.500000
# 2       729.166667
# 3       941.000000
# 4       787.833333
#           ...
# 116     985.333333
# 117     988.333333
# 118     333.333333
# 119     987.833333
# 120     987.833333
# Length: 121, dtype: float64

# %%
df_hanji.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df_g = pd.read_csv("/Users/parkseoyoung/Desktop/aipSources/garlic.csv",  encoding='cp949')
df_g.head()
# Out:
#        거래일자  저장형 한지 1.0 kg 상자 /특  저장형 한지 1.0 kg 상자 /상  저장형 한지 1.0 kg 상자 /중  \
# 0  2011.1.1                 4800                 4200                    0
# 1  2011.2.1                    0                    0                    0
# 2  2011.3.1                 4375                    0                    0
# 3  2011.4.1                    0                    0                    0
# 4  2011.5.1                    0                    0                    0
#
#    저장형 한지 1.0 kg 상자 /하  저장형 한지 반입량  저장형 난지 1.0 kg 상자 /특  저장형 난지 1.0 kg 상자 /상  \
# 0                    0       15946                    0                 2692
# 1                    0       37586                    0                    0
# 2                    0       47354                    0                 2662
# 3                    0       43815                    0                 2665
# 4                    0       93446                    0                    0
#
# ...

# %%
df_g = df_g.replace(0, np.NaN)   
df_g.head()
# Out:
#        거래일자  저장형 한지 1.0 kg 상자 /특  저장형 한지 1.0 kg 상자 /상  저장형 한지 1.0 kg 상자 /중  \
# 0  2011.1.1               4800.0               4200.0                  NaN
# 1  2011.2.1                  NaN                  NaN                  NaN
# 2  2011.3.1               4375.0                  NaN                  NaN
# 3  2011.4.1                  NaN                  NaN                  NaN
# 4  2011.5.1                  NaN                  NaN                  NaN
#
#    저장형 한지 1.0 kg 상자 /하  저장형 한지 반입량  저장형 난지 1.0 kg 상자 /특  저장형 난지 1.0 kg 상자 /상  \
# 0                  NaN     15946.0                  NaN               2692.0
# 1                  NaN     37586.0                  NaN                  NaN
# 2                  NaN     47354.0                  NaN               2662.0
# 3                  NaN     43815.0                  NaN               2665.0
# 4                  NaN     93446.0                  NaN                  NaN
#
# ...

# %%
df_g = df_g.drop(['저장형 난지 1.0 kg 상자 /특','저장형 난지 1.0 kg 상자 /상','저장형 난지 1.0 kg 상자 /중','햇마늘 난지 1.0 kg 상자 /특',
                 '햇마늘 난지 1.0 kg 상자 /상','햇마늘 난지 1.0 kg 상자 /하'],axis=1)
df_g.head()
# Out:
#        거래일자  저장형 한지 1.0 kg 상자 /특  저장형 한지 1.0 kg 상자 /상  저장형 한지 1.0 kg 상자 /중  \
# 0  2011.1.1               4800.0               4200.0                  NaN
# 1  2011.2.1                  NaN                  NaN                  NaN
# 2  2011.3.1               4375.0                  NaN                  NaN
# 3  2011.4.1                  NaN                  NaN                  NaN
# 4  2011.5.1                  NaN                  NaN                  NaN
#
#    저장형 한지 1.0 kg 상자 /하  저장형 한지 반입량  저장형 난지 반입량  햇마늘 한지 1.0 kg 상자 /특  \
# 0                  NaN     15946.0     72399.0                  NaN
# 1                  NaN     37586.0     74785.0                  NaN
# 2                  NaN     47354.0     71940.0                  NaN
# 3                  NaN     43815.0     49300.0                  NaN
# 4                  NaN     93446.0     39143.0                  NaN
#
#    햇마늘 한지 1.0 kg 상자 /하  햇마늘 한지 반입량  햇마늘 난지 반입량  육쪽마늘 1.0 kg 상자 /특  \
# ...

# %%
df_g = df_g.drop(['육쪽마늘 1.0 kg 상자 /특','육쪽마늘 1.0 kg 상자 /상','육쪽마늘 1.0 kg 상자 /중','육쪽마늘 반입량'],axis=1)
df_g.head()
# Out:
#        거래일자  저장형 한지 1.0 kg 상자 /특  저장형 한지 1.0 kg 상자 /상  저장형 한지 1.0 kg 상자 /중  \
# 0  2011.1.1               4800.0               4200.0                  NaN
# 1  2011.2.1                  NaN                  NaN                  NaN
# 2  2011.3.1               4375.0                  NaN                  NaN
# 3  2011.4.1                  NaN                  NaN                  NaN
# 4  2011.5.1                  NaN                  NaN                  NaN
#
#    저장형 한지 1.0 kg 상자 /하  저장형 한지 반입량  저장형 난지 반입량  햇마늘 한지 1.0 kg 상자 /특  \
# 0                  NaN     15946.0     72399.0                  NaN
# 1                  NaN     37586.0     74785.0                  NaN
# 2                  NaN     47354.0     71940.0                  NaN
# 3                  NaN     43815.0     49300.0                  NaN
# 4                  NaN     93446.0     39143.0                  NaN
#
#    햇마늘 한지 1.0 kg 상자 /하  햇마늘 한지 반입량  햇마늘 난지 반입량
# 0                  NaN       692.0      1376.0
# ...

# %%
df_g = df_g.drop(['저장형 한지 1.0 kg 상자 /특','저장형 한지 1.0 kg 상자 /상','저장형 한지 1.0 kg 상자 /중','저장형 한지 1.0 kg 상자 /하',
                 '햇마늘 한지 1.0 kg 상자 /특','햇마늘 한지 1.0 kg 상자 /하'],axis=1)
df_g.head()
# Out:
#        거래일자  저장형 한지 반입량  저장형 난지 반입량  햇마늘 한지 반입량  햇마늘 난지 반입량
# 0  2011.1.1     15946.0     72399.0       692.0      1376.0
# 1  2011.2.1     37586.0     74785.0       832.0      2047.0
# 2  2011.3.1     47354.0     71940.0      1451.0      9384.0
# 3  2011.4.1     43815.0     49300.0       543.0      7267.0
# 4  2011.5.1     93446.0     39143.0     16508.0    506346.0

# %%
### ----------------------------------------------------------------------------------- 전처리한 난지,한지 가격 데이터 붙이기

# %%
df_g['price_nanji'] = df_nanji
df_g
# Out:
#           거래일자  저장형 한지 반입량  저장형 난지 반입량  햇마늘 한지 반입량  햇마늘 난지 반입량  price_nanji
# 0     2011.1.1     15946.0     72399.0       692.0      1376.0   448.666667
# 1     2011.2.1     37586.0     74785.0       832.0      2047.0   460.166667
# 2     2011.3.1     47354.0     71940.0      1451.0      9384.0   913.666667
# 3     2011.4.1     43815.0     49300.0       543.0      7267.0   908.166667
# 4     2011.5.1     93446.0     39143.0     16508.0    506346.0   308.833333
# ..         ...         ...         ...         ...         ...          ...
# 116   2020.9.1    119859.0      2696.0     39505.0      5664.0   983.000000
# 117  2020.10.1    107715.0      1780.0     80952.0      4341.0   987.500000
# 118  2020.11.1    126799.0      1114.0     70907.0      6822.0   985.333333
# 119  2020.12.1     63974.0      1205.0     71747.0      4289.0   984.666667
# 120   2021.1.1         NaN         NaN         NaN         NaN   986.500000
#
# [121 rows x 6 columns]

# %%
df_g['price_hanji'] = df_hanji
df_g
# Out:
#           거래일자  저장형 한지 반입량  저장형 난지 반입량  햇마늘 한지 반입량  햇마늘 난지 반입량  price_nanji  \
# 0     2011.1.1     15946.0     72399.0       692.0      1376.0   448.666667
# 1     2011.2.1     37586.0     74785.0       832.0      2047.0   460.166667
# 2     2011.3.1     47354.0     71940.0      1451.0      9384.0   913.666667
# 3     2011.4.1     43815.0     49300.0       543.0      7267.0   908.166667
# 4     2011.5.1     93446.0     39143.0     16508.0    506346.0   308.833333
# ..         ...         ...         ...         ...         ...          ...
# 116   2020.9.1    119859.0      2696.0     39505.0      5664.0   983.000000
# 117  2020.10.1    107715.0      1780.0     80952.0      4341.0   987.500000
# 118  2020.11.1    126799.0      1114.0     70907.0      6822.0   985.333333
# 119  2020.12.1     63974.0      1205.0     71747.0      4289.0   984.666667
# 120   2021.1.1         NaN         NaN         NaN         NaN   986.500000
#
#      price_hanji
# 0    1500.000000
# 1     708.500000
# ...

# %%
### -------------------------------------------------------------------------------------------------------- 반입량 처리

# %%
import_quantity_nanji = df_g[['저장형 난지 반입량','햇마늘 난지 반입량']]

import_quantity_nanji
# Out:
#      저장형 난지 반입량  햇마늘 난지 반입량
# 0       72399.0      1376.0
# 1       74785.0      2047.0
# 2       71940.0      9384.0
# 3       49300.0      7267.0
# 4       39143.0    506346.0
# ..          ...         ...
# 116      2696.0      5664.0
# 117      1780.0      4341.0
# 118      1114.0      6822.0
# 119      1205.0      4289.0
# 120         NaN         NaN
#
# [121 rows x 2 columns]

# %%
import_quantity_hanji = df_g[['저장형 한지 반입량','햇마늘 한지 반입량']]

import_quantity_hanji
# Out:
#      저장형 한지 반입량  햇마늘 한지 반입량
# 0       15946.0       692.0
# 1       37586.0       832.0
# 2       47354.0      1451.0
# 3       43815.0       543.0
# 4       93446.0     16508.0
# ..          ...         ...
# 116    119859.0     39505.0
# 117    107715.0     80952.0
# 118    126799.0     70907.0
# 119     63974.0     71747.0
# 120         NaN         NaN
#
# [121 rows x 2 columns]

# %%
import_quantity_nanji = import_quantity_nanji.sum(axis=1)
import_quantity_nanji
# Out:
# 0       73775.0
# 1       76832.0
# 2       81324.0
# 3       56567.0
# 4      545489.0
#          ...
# 116      8360.0
# 117      6121.0
# 118      7936.0
# 119      5494.0
# 120         0.0
# Length: 121, dtype: float64

# %%
import_quantity_hanji = import_quantity_hanji.sum(axis=1)
import_quantity_hanji
# Out:
# 0       16638.0
# 1       38418.0
# 2       48805.0
# 3       44358.0
# 4      109954.0
#          ...
# 116    159364.0
# 117    188667.0
# 118    197706.0
# 119    135721.0
# 120         0.0
# Length: 121, dtype: float64

# %%
df_g['import_quantity_nanji'] = import_quantity_nanji
df_g['import_quantity_hanji'] = import_quantity_hanji
df_g
# Out:
#           거래일자  저장형 한지 반입량  저장형 난지 반입량  햇마늘 한지 반입량  햇마늘 난지 반입량  price_nanji  \
# 0     2011.1.1     15946.0     72399.0       692.0      1376.0   448.666667
# 1     2011.2.1     37586.0     74785.0       832.0      2047.0   460.166667
# 2     2011.3.1     47354.0     71940.0      1451.0      9384.0   913.666667
# 3     2011.4.1     43815.0     49300.0       543.0      7267.0   908.166667
# 4     2011.5.1     93446.0     39143.0     16508.0    506346.0   308.833333
# ..         ...         ...         ...         ...         ...          ...
# 116   2020.9.1    119859.0      2696.0     39505.0      5664.0   983.000000
# 117  2020.10.1    107715.0      1780.0     80952.0      4341.0   987.500000
# 118  2020.11.1    126799.0      1114.0     70907.0      6822.0   985.333333
# 119  2020.12.1     63974.0      1205.0     71747.0      4289.0   984.666667
# 120   2021.1.1         NaN         NaN         NaN         NaN   986.500000
#
# ...

# %%
df_g = df_g.drop(['저장형 한지 반입량','저장형 난지 반입량','햇마늘 한지 반입량','햇마늘 난지 반입량'],axis=1)
df_g.head()
# Out:
#        거래일자  price_nanji  price_hanji  import_quantity_nanji  \
# 0  2011.1.1   448.666667  1500.000000                73775.0
# 1  2011.2.1   460.166667   708.500000                76832.0
# 2  2011.3.1   913.666667   729.166667                81324.0
# 3  2011.4.1   908.166667   941.000000                56567.0
# 4  2011.5.1   308.833333   787.833333               545489.0
#
#    import_quantity_hanji
# 0                16638.0
# 1                38418.0
# 2                48805.0
# 3                44358.0
# 4               109954.0

# %%
df_g = df_g.rename(columns={'거래일자':'Date'})
df_g
# Out:
#           Date  price_nanji  price_hanji  import_quantity_nanji  \
# 0     2011.1.1   448.666667  1500.000000                73775.0
# 1     2011.2.1   460.166667   708.500000                76832.0
# 2     2011.3.1   913.666667   729.166667                81324.0
# 3     2011.4.1   908.166667   941.000000                56567.0
# 4     2011.5.1   308.833333   787.833333               545489.0
# ..         ...          ...          ...                    ...
# 116   2020.9.1   983.000000   985.333333                 8360.0
# 117  2020.10.1   987.500000   988.333333                 6121.0
# 118  2020.11.1   985.333333   333.333333                 7936.0
# 119  2020.12.1   984.666667   987.833333                 5494.0
# 120   2021.1.1   986.500000   987.833333                    0.0
#
#      import_quantity_hanji
# 0                  16638.0
# 1                  38418.0
# 2                  48805.0
# 3                  44358.0
# 4                 109954.0
# ..                     ...
# ...

# %%
df_g = df_g.replace(0, np.NaN)
df_g
# Out:
#           Date  price_nanji  price_hanji  import_quantity_nanji  \
# 0     2011.1.1   448.666667  1500.000000                73775.0
# 1     2011.2.1   460.166667   708.500000                76832.0
# 2     2011.3.1   913.666667   729.166667                81324.0
# 3     2011.4.1   908.166667   941.000000                56567.0
# 4     2011.5.1   308.833333   787.833333               545489.0
# ..         ...          ...          ...                    ...
# 116   2020.9.1   983.000000   985.333333                 8360.0
# 117  2020.10.1   987.500000   988.333333                 6121.0
# 118  2020.11.1   985.333333   333.333333                 7936.0
# 119  2020.12.1   984.666667   987.833333                 5494.0
# 120   2021.1.1   986.500000   987.833333                    NaN
#
#      import_quantity_hanji
# 0                  16638.0
# 1                  38418.0
# 2                  48805.0
# 3                  44358.0
# 4                 109954.0
# ..                     ...
# ...

# %%
df_g.isnull().sum()
# Out:
# Date                     0
# price_nanji              0
# price_hanji              0
# import_quantity_nanji    1
# import_quantity_hanji    1
# dtype: int64

# %%
### ------------------------------------------------------------------------------ 반입량의 NaN 값은 최빈값으로 대체 fillNa

# %%
most_freq = df_g['import_quantity_nanji'].value_counts(dropna=True).idxmax()
df_g['import_quantity_nanji'].fillna(most_freq, inplace = True)

most_freq_hanji= df_g['import_quantity_hanji'].value_counts(dropna=True).idxmax()
df_g['import_quantity_hanji'].fillna(most_freq_hanji, inplace = True)

# %%
df_g.isnull().sum()
# Out:
# Date                     0
# price_nanji              0
# price_hanji              0
# import_quantity_nanji    0
# import_quantity_hanji    0
# dtype: int64

# %%
### --------------------------------------------------------------------------------------------------------기상 데이터 추가

## 한지와 난지 모델 분류



#   df_temphigh_nanji  ,  df_temphigh_hanji
#   df_rain_nanji   ,    df_rain_hanji
#   df_tempavg_nanji  , df_tempavg_hanji
#    df_templow_nanji  ,  df_templow_hanji

# %%
df_temphigh = pd.read_csv("/Users/parkseoyoung/Desktop/aipSources/garlic_weather_tempHigh.csv")
df_temphigh.head()
# Out:
#         일자  고흥 최고기온  서귀포 최고기온  서산 최고기온  영천 최고기온  의성 최고기온  합천 최고기온
# 0  2011-01      8.3      10.7      3.4      6.4      5.1      7.1
# 1  2011-02     19.2      18.2     14.3     19.1     18.2     21.3
# 2  2011-03     21.3      18.9     14.8     21.9     21.4     22.9
# 3  2011-04     23.4      24.5     18.9     27.7     28.1     29.2
# 4  2011-05     29.0      26.4     28.3     28.5     29.0     28.6

# %%
df_temphigh_nanji = df_temphigh[['고흥 최고기온','서귀포 최고기온','영천 최고기온','합천 최고기온']]

df_temphigh_nanji
# Out:
#      고흥 최고기온  서귀포 최고기온  영천 최고기온  합천 최고기온
# 0        8.3      10.7      6.4      7.1
# 1       19.2      18.2     19.1     21.3
# 2       21.3      18.9     21.9     22.9
# 3       23.4      24.5     27.7     29.2
# 4       29.0      26.4     28.5     28.6
# ..       ...       ...      ...      ...
# 126     33.1      32.0     36.4     35.7
# 127     34.6      32.9     35.1     36.6
# 128     29.7      29.5     30.1     30.2
# 129     29.2      28.7     30.5     30.9
# 130     21.6      22.3     19.9     21.8
#
# [131 rows x 4 columns]

# %%
df_temphigh_nanji = df_temphigh_nanji.mean(axis=1)     ## 난지 최고기온
df_temphigh_nanji
# Out:
# 0       8.125
# 1      19.450
# 2      21.250
# 3      26.200
# 4      28.125
#         ...
# 126    34.300
# 127    34.800
# 128    29.875
# 129    29.825
# 130    21.400
# Length: 131, dtype: float64

# %%
df_temphigh_hanji = df_temphigh[['서산 최고기온','의성 최고기온']]

df_temphigh_hanji
# Out:
#      서산 최고기온  의성 최고기온
# 0        3.4      5.1
# 1       14.3     18.2
# 2       14.8     21.4
# 3       18.9     28.1
# 4       28.3     29.0
# ..       ...      ...
# 126     35.8     36.5
# 127     34.5     37.0
# 128     29.9     30.0
# 129     28.2     30.2
# 130     17.9     19.7
#
# [131 rows x 2 columns]

# %%
df_temphigh_hanji = df_temphigh_hanji.mean(axis=1)     ## 한지 최고기온
df_temphigh_hanji
# Out:
# 0       4.25
# 1      16.25
# 2      18.10
# 3      23.50
# 4      28.65
#        ...
# 126    36.15
# 127    35.75
# 128    29.95
# 129    29.20
# 130    18.80
# Length: 131, dtype: float64

# %%
df_rain = pd.read_csv("/Users/parkseoyoung/Desktop/aipSources/garlic_weather_Rain.csv")
df_rain.head()
# Out:
#          일자  고흥 강수량  서귀포 강수량  서산 강수량  영천 강수량  의성 강수량  합천 강수량
# 0  2011.1.1     0.0      5.2     8.8     0.2     0.3     0.9
# 1  2011.2.1    85.5     34.1    55.8    66.9    55.6    63.0
# 2  2011.3.1    40.0     91.6    34.5    17.0    13.2    14.5
# 3  2011.4.1   109.8    148.4    96.2   114.5    81.2   103.0
# 4  2011.5.1   158.7    125.4   107.9   169.1   124.8   127.9

# %%
df_rain_nanji = df_rain[['고흥 강수량','서귀포 강수량','영천 강수량','합천 강수량']]

df_rain_nanji
# Out:
#      고흥 강수량  서귀포 강수량  영천 강수량  합천 강수량
# 0       0.0      5.2     0.2     0.9
# 1      85.5     34.1    66.9    63.0
# 2      40.0     91.6    17.0    14.5
# 3     109.8    148.4   114.5   103.0
# 4     158.7    125.4   169.1   127.9
# ..      ...      ...     ...     ...
# 116   256.0    424.9   201.6   193.0
# 117    24.9     39.2    11.1    16.3
# 118     9.1     11.7    32.8    17.8
# 119     9.4     62.9     0.9     5.4
# 120    19.8     54.6    11.9    16.9
#
# [121 rows x 4 columns]

# %%
df_rain_nanji = df_rain_nanji.mean(axis=1)    
df_rain_nanji
# Out:
# 0        1.575
# 1       62.375
# 2       40.775
# 3      118.925
# 4      145.275
#         ...
# 116    268.875
# 117     22.875
# 118     17.850
# 119     19.650
# 120     25.800
# Length: 121, dtype: float64

# %%
df_rain_hanji = df_rain[['서산 강수량','의성 강수량']]

df_rain_hanji
# Out:
#      서산 강수량  의성 강수량
# 0       8.8     0.3
# 1      55.8    55.6
# 2      34.5    13.2
# 3      96.2    81.2
# 4     107.9   124.8
# ..      ...     ...
# 116   257.7   116.5
# 117    12.6     4.6
# 118    72.0    45.1
# 119     9.7     1.4
# 120    25.3     8.6
#
# [121 rows x 2 columns]

# %%
df_rain_hanji = df_rain_hanji.mean(axis=1)    
df_rain_hanji
# Out:
# 0        4.55
# 1       55.70
# 2       23.85
# 3       88.70
# 4      116.35
#         ...
# 116    187.10
# 117      8.60
# 118     58.55
# 119      5.55
# 120     16.95
# Length: 121, dtype: float64

# %%
df_tempAvg = pd.read_csv("/Users/parkseoyoung/Desktop/aipSources/garlic_weather_tempAverage.csv")
df_tempAvg.head()
# Out:
#         일자  고흥 평균기온  서귀포 평균기온  서산 평균기온  영천 평균기온  의성 평균기온  합천 평균기온
# 0  2011-01    -1.65      3.97    -5.09    -3.72    -6.94    -3.88
# 1  2011-02     3.65      8.98     0.84     1.92     0.10     2.25
# 2  2011-03     5.91      9.32     3.53     5.22     3.57     5.64
# 3  2011-04    12.20     14.16     9.51    11.78    10.93    12.77
# 4  2011-05    17.73     18.69    16.49    16.81    17.00    18.03

# %%
df_tempavg_nanji = df_tempAvg[['고흥 평균기온','서귀포 평균기온','영천 평균기온','합천 평균기온']]
df_tempavg_nanji = df_tempavg_nanji.mean(axis=1)    
df_tempavg_nanji
# Out:
# 0      -1.3200
# 1       4.2000
# 2       6.5225
# 3      12.7275
# 4      17.8150
#         ...
# 126    25.9325
# 127    25.3650
# 128    22.1325
# 129    16.7550
# 130    14.1000
# Length: 131, dtype: float64

# %%
df_tempavg_hanji = df_tempAvg[['서산 평균기온','의성 평균기온']]
df_tempavg_hanji = df_tempavg_hanji.mean(axis=1)    
df_tempavg_hanji
# Out:
# 0      -6.015
# 1       0.470
# 2       3.550
# 3      10.220
# 4      16.745
#         ...
# 126    26.225
# 127    24.830
# 128    21.195
# 129    14.510
# 130    10.950
# Length: 131, dtype: float64

# %%
df_tempLow = pd.read_csv("/Users/parkseoyoung/Desktop/aipSources/garlic_weather_tempLow.csv")
df_tempLow.head()
# Out:
#         일자  고흥 최저기온  서귀포 최저기온  서산 최저기온  영천 최저기온  의성 최저기온  합천 최저기온
# 0  2011-01     -9.6      -3.7    -14.7    -15.1    -21.1    -16.4
# 1  2011-02     -8.7      -1.9    -10.3    -11.3    -14.0    -10.8
# 2  2011-03     -5.1       1.8     -6.5     -6.6     -9.5     -6.3
# 3  2011-04     -0.4       6.8     -1.2     -3.2     -4.5     -1.7
# 4  2011-05      6.0      12.5      5.6      5.6      3.4      6.5

# %%
df_templow_nanji = df_tempLow[['고흥 최저기온','서귀포 최저기온','영천 최저기온','합천 최저기온']]
df_templow_nanji = df_templow_nanji.mean(axis=1)    
df_templow_nanji
# Out:
# 0     -11.200
# 1      -8.175
# 2      -4.050
# 3       0.375
# 4       7.650
#         ...
# 126    18.650
# 127    19.725
# 128    15.050
# 129     2.750
# 130     8.825
# Length: 131, dtype: float64

# %%
df_templow_hanji = df_tempLow[['서산 최저기온','의성 최저기온']]
df_templow_hanji = df_templow_hanji.mean(axis=1)    
df_templow_hanji
# Out:
# 0     -17.90
# 1     -12.15
# 2      -8.00
# 3      -2.85
# 4       4.50
#        ...
# 126    17.65
# 127    18.00
# 128    13.20
# 129    -0.15
# 130     5.85
# Length: 131, dtype: float64

# %%
### -------------------------------------------------------------------------------------------------------df_g에 합치기

# %%
### --------------------------------------------------------------------------------------------------------기상 데이터 추가

## 한지와 난지 모델 분류



#   df_temphigh_nanji  ,  df_temphigh_hanji
#   df_rain_nanji   ,    df_rain_hanji
#   df_tempavg_nanji  , df_tempavg_hanji
#    df_templow_nanji  ,  df_templow_hanji

# %%
df_g
# Out:
#           Date  price_nanji  price_hanji  import_quantity_nanji  \
# 0     2011.1.1   448.666667  1500.000000                73775.0
# 1     2011.2.1   460.166667   708.500000                76832.0
# 2     2011.3.1   913.666667   729.166667                81324.0
# 3     2011.4.1   908.166667   941.000000                56567.0
# 4     2011.5.1   308.833333   787.833333               545489.0
# ..         ...          ...          ...                    ...
# 116   2020.9.1   983.000000   985.333333                 8360.0
# 117  2020.10.1   987.500000   988.333333                 6121.0
# 118  2020.11.1   985.333333   333.333333                 7936.0
# 119  2020.12.1   984.666667   987.833333                 5494.0
# 120   2021.1.1   986.500000   987.833333               124727.0
#
#      import_quantity_hanji
# 0                  16638.0
# 1                  38418.0
# 2                  48805.0
# 3                  44358.0
# 4                 109954.0
# ..                     ...
# ...

# %%
df_nanji = df_g[['Date','price_nanji','import_quantity_nanji']]    
df_nanji['temphigh_nanji'] = df_temphigh_nanji
df_nanji['tempavg_nanji'] = df_tempavg_nanji
df_nanji['templow_nanji'] = df_templow_nanji
df_nanji['rain_nanji'] = df_rain_nanji

df_nanji
# Out:
# <ipython-input-60-32852242fb06>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nanji['temphigh_nanji'] = df_temphigh_nanji
#           Date  price_nanji  import_quantity_nanji  temphigh_nanji  \
# 0     2011.1.1   448.666667                73775.0           8.125
# 1     2011.2.1   460.166667                76832.0          19.450
# 2     2011.3.1   913.666667                81324.0          21.250
# 3     2011.4.1   908.166667                56567.0          26.200
# 4     2011.5.1   308.833333               545489.0          28.125
# ..         ...          ...                    ...             ...
# 116   2020.9.1   983.000000                 8360.0          29.650
# ...

# %%
df_nanji
# Out:
#           Date  price_nanji  import_quantity_nanji  temphigh_nanji  \
# 0     2011.1.1   448.666667                73775.0           8.125
# 1     2011.2.1   460.166667                76832.0          19.450
# 2     2011.3.1   913.666667                81324.0          21.250
# 3     2011.4.1   908.166667                56567.0          26.200
# 4     2011.5.1   308.833333               545489.0          28.125
# ..         ...          ...                    ...             ...
# 116   2020.9.1   983.000000                 8360.0          29.650
# 117  2020.10.1   987.500000                 6121.0          25.625
# 118  2020.11.1   985.333333                 7936.0          23.325
# 119  2020.12.1   984.666667                 5494.0          13.725
# 120   2021.1.1   986.500000               124727.0          16.600
#
#      tempavg_nanji  templow_nanji  rain_nanji
# 0          -1.3200        -11.200       1.575
# 1           4.2000         -8.175      62.375
# ...

# %%
df_hanji = df_g[['Date','price_hanji','import_quantity_hanji']]    
df_hanji['temphigh_hanji'] = df_temphigh_hanji
df_hanji['tempavg_hanji'] = df_tempavg_hanji
df_hanji['templow_hanji'] = df_templow_hanji
df_hanji['rain_hanji'] = df_rain_hanji

df_hanji
# Out:
# <ipython-input-62-2149d3c89029>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hanji['temphigh_hanji'] = df_temphigh_hanji
#           Date  price_hanji  import_quantity_hanji  temphigh_hanji  \
# 0     2011.1.1  1500.000000                16638.0            4.25
# 1     2011.2.1   708.500000                38418.0           16.25
# 2     2011.3.1   729.166667                48805.0           18.10
# 3     2011.4.1   941.000000                44358.0           23.50
# 4     2011.5.1   787.833333               109954.0           28.65
# ..         ...          ...                    ...             ...
# 116   2020.9.1   985.333333               159364.0           29.75
# ...

# %%
df_hanji
# Out:
#           Date  price_hanji  import_quantity_hanji  temphigh_hanji  \
# 0     2011.1.1  1500.000000                16638.0            4.25
# 1     2011.2.1   708.500000                38418.0           16.25
# 2     2011.3.1   729.166667                48805.0           18.10
# 3     2011.4.1   941.000000                44358.0           23.50
# 4     2011.5.1   787.833333               109954.0           28.65
# ..         ...          ...                    ...             ...
# 116   2020.9.1   985.333333               159364.0           29.75
# 117  2020.10.1   988.333333               188667.0           24.90
# 118  2020.11.1   333.333333               197706.0           22.20
# 119  2020.12.1   987.833333               135721.0           12.50
# 120   2021.1.1   987.833333              1592282.0           13.80
#
#      tempavg_hanji  templow_hanji  rain_hanji
# 0           -6.015         -17.90        4.55
# 1            0.470         -12.15       55.70
# ...

# %%
### ---------------------------------------------------------------------------------------------------- 난지 학습시작

# %%
df_nanji['price_nanji'].describe()
# Out:
# count     121.000000
# mean      760.504132
# std       306.600992
# min       100.000000
# 25%       575.333333
# 50%       687.000000
# 75%       985.333333
# max      2350.000000
# Name: price_nanji, dtype: float64

# %%
df_nanji['price_nanji'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
### numerical features(except "LON" & "LAT") :  LON, LAT: 해당 지역의 경도(Longitudes) 위도(Latitudes) 정보
numerical_columns=['import_quantity_nanji','temphigh_nanji','tempavg_nanji','templow_nanji','rain_nanji']

### figsize()는 plot()의 기본 크기를 지정합니다. 
fig = plt.figure(figsize = (16, 20))
ax = fig.gca()  # Axes 생성

### gca(), gcf(), axis()
### gca()로 현재의 Axes를, gcf()로 현재의 Figure 객체를 구할 수 있다.
### ax=plt.gica(): 축의 위치를 호출하여 ax로 설정(축 위치 변경을 위해 필요한 과정)

df_nanji[numerical_columns].hist(ax=ax)
plt.show()
# Out:
# <ipython-input-66-cd1ea1dfd37b>:12: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_nanji[numerical_columns].hist(ax=ax)

# %%
cols = ['price_nanji', 'import_quantity_nanji','temphigh_nanji','tempavg_nanji','templow_nanji','rain_nanji']

corr = df_nanji[cols].corr(method = 'pearson')
corr
# Out:
#                        price_nanji  import_quantity_nanji  temphigh_nanji  \
# price_nanji               1.000000              -0.059679       -0.206981
# import_quantity_nanji    -0.059679               1.000000        0.328874
# temphigh_nanji           -0.206981               0.328874        1.000000
# tempavg_nanji            -0.191919               0.322291        0.973342
# templow_nanji            -0.166392               0.323166        0.888457
# rain_nanji               -0.266816               0.136236        0.685856
#
#                        tempavg_nanji  templow_nanji  rain_nanji
# price_nanji                -0.191919      -0.166392   -0.266816
# import_quantity_nanji       0.322291       0.323166    0.136236
# temphigh_nanji              0.973342       0.888457    0.685856
# tempavg_nanji               1.000000       0.938252    0.711127
# templow_nanji               0.938252       1.000000    0.663515
# rain_nanji                  0.711127       0.663515    1.000000

# %%
fig = plt.figure(figsize = (16, 12))
ax = fig.gca()

# https://seaborn.pydata.org/generated/seaborn.heatmap.html
sns.set(font_scale = 1.5)  # heatmap 안의 font-size 설정 
heatmap = sns.heatmap(corr.values, annot = True, fmt='.2f', annot_kws={'size':15},
                      yticklabels = cols, xticklabels = cols, ax=ax, cmap = "RdYlBu")
plt.tight_layout()
plt.show()

# %%
### scatter plot 산점도, https://seaborn.pydata.org/generated/seaborn.scatterplot.html

## 반입량과 가격 상관 관계
sns.scatterplot(data=df_nanji, x='import_quantity_nanji', y='price_nanji', markers='o', color='blue', alpha=0.6)
plt.title('Scatter Plot')
plt.show()

# %%
## 강수량과 가격 상관 관계
sns.scatterplot(data=df_nanji, x='rain_nanji', y='price_nanji', markers='o', color='blue', alpha=0.6)
plt.title('Scatter Plot')
plt.show()

# %%
## 평균기온과 가격 상관 관계
sns.scatterplot(data=df_nanji, x='tempavg_nanji', y='price_nanji', markers='o', color='blue', alpha=0.6)
plt.title('Scatter Plot')
plt.show()

# %%
## 평균기온과 가격 상관 관계
sns.scatterplot(data=df_nanji, x='temphigh_nanji', y='price_nanji', markers='o', color='blue', alpha=0.6)
plt.title('Scatter Plot')
plt.show()

# %%
## 평균기온과 가격 상관 관계
sns.scatterplot(data=df_nanji, x='templow_nanji', y='price_nanji', markers='o', color='blue', alpha=0.6)
plt.title('Scatter Plot')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# feature standardization  (numerical_columns except dummy var.-"CHAS")

scaler = StandardScaler()  # 평균 0, 표준편차 1
scale_columns = ['import_quantity_nanji','temphigh_nanji','tempavg_nanji','templow_nanji','rain_nanji']
df_nanji[scale_columns] = scaler.fit_transform(df_nanji[scale_columns])

# %%
df_nanji.head()
# Out:
#        Date  price_nanji  import_quantity_nanji  temphigh_nanji  \
# 0  2011.1.1   448.666667              -0.480629       -2.342662
# 1  2011.2.1   460.166667              -0.473439       -0.815573
# 2  2011.3.1   913.666667              -0.462874       -0.572857
# 3  2011.4.1   908.166667              -0.521101        0.094612
# 4  2011.5.1   308.833333               0.628804        0.354184
#
#    tempavg_nanji  templow_nanji  rain_nanji
# 0      -1.825122      -1.438914   -1.200309
# 1      -1.175005      -1.139248   -0.606695
# 2      -0.901473      -0.730612   -0.817585
# 3      -0.170681      -0.292257   -0.054576
# 4       0.428498       0.428428    0.202689

# %%
df_nanji[scale_columns].head()
# Out:
#    import_quantity_nanji  temphigh_nanji  tempavg_nanji  templow_nanji  \
# 0              -0.480629       -2.342662      -1.825122      -1.438914
# 1              -0.473439       -0.815573      -1.175005      -1.139248
# 2              -0.462874       -0.572857      -0.901473      -0.730612
# 3              -0.521101        0.094612      -0.170681      -0.292257
# 4               0.628804        0.354184       0.428498       0.428428
#
#    rain_nanji
# 0   -1.200309
# 1   -0.606695
# 2   -0.817585
# 3   -0.054576
# 4    0.202689

# %%
from sklearn.model_selection import train_test_split

# split dataset into training & test
X = df_nanji[numerical_columns]
y = df_nanji['price_nanji']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train.shape, y_train.shape
# Out:
# ((96, 5), (96,))

# %%
X_train.shape, y_train.shape
# Out:
# ((96, 5), (96,))

# %%
y_train
# Out:
# 97     1103.666667
# 35      525.166667
# 44      916.666667
# 93      901.833333
# 115     782.666667
#           ...
# 9       267.166667
# 72     1183.166667
# 12      772.500000
# 107     661.166667
# 37      478.166667
# Name: price_nanji, Length: 96, dtype: float64

# %%
X_train
# Out:
#      import_quantity_nanji  temphigh_nanji  tempavg_nanji  templow_nanji  \
# 97               -0.606280       -1.203245      -1.099041      -0.829675
# 35               -0.360794       -1.486414      -1.219465      -0.911402
# 44               -0.107753        0.721629       0.886348       0.946034
# 93               -0.521042        0.108097       0.035130       0.039605
# 115              -0.629762        1.169980       1.522626       1.867322
# ..                     ...             ...            ...            ...
# 9                -0.377295        0.266536       0.170866      -0.104037
# 72               -0.559091       -1.472929      -1.368450      -1.141724
# 12               -0.559331       -1.833632      -1.465320      -1.268030
# 107              -0.594939       -1.095371      -1.375811      -3.063552
# 37               -0.514760       -0.640278      -1.123184      -0.899019
#
#      rain_nanji
# 97    -0.894471
# 35    -1.110730
# 44     0.118724
# 93     0.660104
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['features'] = X_train.columns
vif["VIF Factor"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif.round(1)
# Out:
#                 features  VIF Factor
# 0  import_quantity_nanji         1.1
# 1         temphigh_nanji        25.5
# 2          tempavg_nanji        67.7
# 3          templow_nanji        21.5
# 4             rain_nanji         2.0

# %%
from sklearn import linear_model

# fit regression model in training set
lr = linear_model.LinearRegression()
model = lr.fit(X_train, y_train)

# predict in test set
pred_test = lr.predict(X_test)

# %%
### print coef 
### 계수를 출력합니다.
print(lr.coef_)
# Out:
# [ -15.17809869 -183.6763108   229.73290281  -25.45668593  -74.73930613]

# %%
coefs = pd.DataFrame(zip(df_nanji[numerical_columns].columns, lr.coef_), columns = ['feature', 'coefficients'])
coefs
# Out:
#                  feature  coefficients
# 0  import_quantity_nanji    -15.178099
# 1         temphigh_nanji   -183.676311
# 2          tempavg_nanji    229.732903
# 3          templow_nanji    -25.456686
# 4             rain_nanji    -74.739306

# %%
coefs_new = coefs.reindex(coefs.coefficients.abs().sort_values(ascending=False).index)
coefs_new
# Out:
#                  feature  coefficients
# 2          tempavg_nanji    229.732903
# 1         temphigh_nanji   -183.676311
# 4             rain_nanji    -74.739306
# 3          templow_nanji    -25.456686
# 0  import_quantity_nanji    -15.178099

# %%
plt.figure(figsize = (8, 8))

### bar plot : matplotlib.pyplot 모듈의 barh() 함수를 사용해서 수평 막대 그래프를 그릴 수 있습니다. 
plt.barh(coefs_new['feature'], coefs_new['coefficients'])
plt.title('"feature - coefficient" Graph')
plt.xlabel('coefficients')
plt.ylabel('features')
plt.show()

# %%
import statsmodels.api as sm

X_train2 = sm.add_constant(X_train)
### 회귀분석모형 수식을 간단하게 만들기 위해 다음과 같이 상수항을 독립변수 데이터에 추가하는 것을 상수항 결합(bias augmentation)작업이라고 합니다.
### ordinary least square 의 약자로, 거리의 최소값을 기준으로 구하는 함수입니다. 

model2 = sm.OLS(y_train, X_train2).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            price_nanji   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     1.210
# Date:                Sun, 14 Nov 2021   Prob (F-statistic):              0.311
# Time:                        04:55:57   Log-Likelihood:                -680.33
# No. Observations:                  96   AIC:                             1373.
# Df Residuals:                      90   BIC:                             1388.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
### 예측 결과 시각화 (test set)
df_1 = pd.DataFrame({'actual': y_test, 'prediction': pred_test})
df_1 = df_1.sort_values(by='actual').reset_index(drop=True)
df_1.head()
# Out:
#        actual  prediction
# 0  100.000000  735.047934
# 1  509.000000  740.241864
# 2  514.166667  704.827525
# 3  541.666667  742.688213
# 4  640.000000  667.344696

# %%
plt.figure(figsize=(12, 9))
plt.scatter(df_1.index, df_1['prediction'], marker='x', color='r')
plt.scatter(df_1.index, df_1['actual'], alpha=0.3, marker='o', color='black')
plt.title("Prediction Result in Test Set", fontsize=20)
plt.legend(['prediction', 'actual'], fontsize=12)
plt.show()

# %%
### numerical features(except "LON" & "LAT") :  LON, LAT: 해당 지역의 경도(Longitudes) 위도(Latitudes) 정보
numerical_columns=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

### figsize()는 plot()의 기본 크기를 지정합니다. 
fig = plt.figure(figsize = (16, 20))
ax = fig.gca()  # Axes 생성

### gca(), gcf(), axis()
### gca()로 현재의 Axes를, gcf()로 현재의 Figure 객체를 구할 수 있다.
### ax=plt.gica(): 축의 위치를 호출하여 ax로 설정(축 위치 변경을 위해 필요한 과정)

df[numerical_columns].hist(ax=ax)
plt.show()
