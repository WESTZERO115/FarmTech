# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("C:/Users/8305-01/Desktop/aipSources/cabbage.csv",  encoding='cp949')
df.head()
# Out:
#          거래일자  봄배추 10.0 kg 상자 /특  봄배추 10.0 kg 상자 /상  봄배추 10.0 kg 상자 /중  \
# 0  2011-01-01                  0                  0                  0
# 1  2011-02-01               1600                  0                  0
# 2  2011-03-01               5878               6333                  0
# 3  2011-04-01               5709               4551               2000
# 4  2011-05-01               3051               2040                  0
#
#    봄배추 10.0 kg 상자 /하   봄배추 반입량  여름배추 10.0 kg 상자 /특  여름배추 10.0 kg 상자 /상  \
# 0                  0    416791                   0                5966
# 1                  0    454298                   0                4573
# 2                  0    517226                   0                5183
# 3                  0   5772481                   0                4143
# 4                  0  20502131                   0                2299
#
#    여름배추 10.0 kg 상자 /중  여름배추 10.0 kg 상자 /하  ...  고냉지배추 10.0 kg 상자 /특  \
# 0                   0                   0  ...                    0
# 1                   0                   0  ...                 6600
# 2                   0                   0  ...                 5950
# 3                   0                   0  ...                  775
# 4                   0                   0  ...                 1700
#
#    고냉지배추 10.0 kg 상자 /상  고냉지배추 10.0 kg 상자 /중  고냉지배추 10.0 kg 상자 /하  고냉지배추 반입량  \
# 0                    0                    0                    0    5316904
# 1                 3650                 3800                    0    6684087
# 2                 4350                 4025                    0    5786184
# 3                  400                    0                    0       6004
# 4                 1100                  800                    0       6100
#
#    저장배추 10.0 kg 상자 /특  저장배추 10.0 kg 상자 /상  저장배추 10.0 kg 상자 /중  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# 2                9799                5189                3650
# 3                8345                4352                3683
# 4                6457                3417                   0
#
#    저장배추 10.0 kg 상자 /하  저장배추 반입량
# 0                   0    375405
# 1                   0    486980
# 2                   0   4945713
# 3                   0  14046697
# 4                 500   2326399
#
# [5 rows x 31 columns]

# %%
df = df.replace(0, np.NaN)   ##################
df.head()
# Out:
#          거래일자  봄배추 10.0 kg 상자 /특  봄배추 10.0 kg 상자 /상  봄배추 10.0 kg 상자 /중  \
# 0  2011-01-01                NaN                NaN                NaN
# 1  2011-02-01             1600.0                NaN                NaN
# 2  2011-03-01             5878.0             6333.0                NaN
# 3  2011-04-01             5709.0             4551.0             2000.0
# 4  2011-05-01             3051.0             2040.0                NaN
#
#    봄배추 10.0 kg 상자 /하     봄배추 반입량  여름배추 10.0 kg 상자 /특  여름배추 10.0 kg 상자 /상  \
# 0                NaN    416791.0                 NaN              5966.0
# 1                NaN    454298.0                 NaN              4573.0
# 2                NaN    517226.0                 NaN              5183.0
# 3                NaN   5772481.0                 NaN              4143.0
# 4                NaN  20502131.0                 NaN              2299.0
#
#    여름배추 10.0 kg 상자 /중  여름배추 10.0 kg 상자 /하  ...  고냉지배추 10.0 kg 상자 /특  \
# 0                 NaN                 NaN  ...                  NaN
# 1                 NaN                 NaN  ...               6600.0
# 2                 NaN                 NaN  ...               5950.0
# 3                 NaN                 NaN  ...                775.0
# 4                 NaN                 NaN  ...               1700.0
#
#    고냉지배추 10.0 kg 상자 /상  고냉지배추 10.0 kg 상자 /중  고냉지배추 10.0 kg 상자 /하  고냉지배추 반입량  \
# 0                  NaN                  NaN                  NaN  5316904.0
# 1               3650.0               3800.0                  NaN  6684087.0
# 2               4350.0               4025.0                  NaN  5786184.0
# 3                400.0                  NaN                  NaN     6004.0
# 4               1100.0                800.0                  NaN     6100.0
#
#    저장배추 10.0 kg 상자 /특  저장배추 10.0 kg 상자 /상  저장배추 10.0 kg 상자 /중  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2              9799.0              5189.0              3650.0
# 3              8345.0              4352.0              3683.0
# 4              6457.0              3417.0                 NaN
#
#    저장배추 10.0 kg 상자 /하    저장배추 반입량
# 0                 NaN    375405.0
# 1                 NaN    486980.0
# 2                 NaN   4945713.0
# 3                 NaN  14046697.0
# 4               500.0   2326399.0
#
# [5 rows x 31 columns]

# %%
# nan 값이 얼마나 있는지 column별로 확인하기
df.isnull().sum()
#################################################################### [중, 하]가 압도적으로 NaN이 많아서 삭제. 이상치라 판단해 많아삭제
# Out:
# 거래일자                        0
# 봄배추 10.0 kg 상자 /특          44
# 봄배추 10.0 kg 상자 /상          36
# 봄배추 10.0 kg 상자 /중          98
# 봄배추 10.0 kg 상자 /하         105
# 봄배추 반입량                     1
# 여름배추 10.0 kg 상자 /특         69
# 여름배추 10.0 kg 상자 /상          8
# 여름배추 10.0 kg 상자 /중        116
# 여름배추 10.0 kg 상자 /하        120
# 여름배추 반입량                    1
# 김장(가을)배추 10.0 kg 상자 /특     80
# 김장(가을)배추 10.0 kg 상자 /상     77
# 김장(가을)배추 10.0 kg 상자 /중    112
# 김장(가을)배추 10.0 kg 상자 /하    120
# 김장(가을)배추 반입량                6
# 월동배추 10.0 kg 상자 /특         11
# 월동배추 10.0 kg 상자 /상         20
# 월동배추 10.0 kg 상자 /중         82
# 월동배추 10.0 kg 상자 /하         90
# 월동배추 반입량                    1
# 고냉지배추 10.0 kg 상자 /특        66
# 고냉지배추 10.0 kg 상자 /상        92
# 고냉지배추 10.0 kg 상자 /중       109
# 고냉지배추 10.0 kg 상자 /하       118
# 고냉지배추 반입량                  17
# 저장배추 10.0 kg 상자 /특         96
# 저장배추 10.0 kg 상자 /상         93
# 저장배추 10.0 kg 상자 /중        115
# 저장배추 10.0 kg 상자 /하        119
# 저장배추 반입량                    2
# dtype: int64

# %%
df.isnull().sum() / len(df)
# Out:
# 거래일자                      0.000000
# 봄배추 10.0 kg 상자 /특         0.363636
# 봄배추 10.0 kg 상자 /상         0.297521
# 봄배추 10.0 kg 상자 /중         0.809917
# 봄배추 10.0 kg 상자 /하         0.867769
# 봄배추 반입량                   0.008264
# 여름배추 10.0 kg 상자 /특        0.570248
# 여름배추 10.0 kg 상자 /상        0.066116
# 여름배추 10.0 kg 상자 /중        0.958678
# 여름배추 10.0 kg 상자 /하        0.991736
# 여름배추 반입량                  0.008264
# 김장(가을)배추 10.0 kg 상자 /특    0.661157
# 김장(가을)배추 10.0 kg 상자 /상    0.636364
# 김장(가을)배추 10.0 kg 상자 /중    0.925620
# 김장(가을)배추 10.0 kg 상자 /하    0.991736
# 김장(가을)배추 반입량              0.049587
# 월동배추 10.0 kg 상자 /특        0.090909
# 월동배추 10.0 kg 상자 /상        0.165289
# 월동배추 10.0 kg 상자 /중        0.677686
# 월동배추 10.0 kg 상자 /하        0.743802
# 월동배추 반입량                  0.008264
# 고냉지배추 10.0 kg 상자 /특       0.545455
# 고냉지배추 10.0 kg 상자 /상       0.760331
# 고냉지배추 10.0 kg 상자 /중       0.900826
# 고냉지배추 10.0 kg 상자 /하       0.975207
# 고냉지배추 반입량                 0.140496
# 저장배추 10.0 kg 상자 /특        0.793388
# 저장배추 10.0 kg 상자 /상        0.768595
# 저장배추 10.0 kg 상자 /중        0.950413
# 저장배추 10.0 kg 상자 /하        0.983471
# 저장배추 반입량                  0.016529
# dtype: float64

# %%
import matplotlib
matplotlib.font_manager._rebuild()
x = ['특', '상', '중','하' ]
y = [204, 132, 408, 435]
plt.bar(x,y)

for i, v in enumerate(x):
    plt.text(v, y[i], y[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 9, 
             color='blue',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')    # verticalalignment (top, center, bottom)

plt.show()


############################# 여기 중, 하 는 너무 NaN 값이 많아 이상치라 판단해 삭제. ###############################
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 53945 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 53945 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
SC = df ['봄배추 반입량']

# %%
SC
# Out:
# 0        416791.0
# 1        454298.0
# 2        517226.0
# 3       5772481.0
# 4      20502131.0
#           ...
# 116     1545054.0
# 117     1367593.0
# 118     2135489.0
# 119     1083070.0
# 120           NaN
# Name: 봄배추 반입량, Length: 121, dtype: float64

# %%
SC = SC.dropna()

# %%
SC
# Out:
# 0        416791.0
# 1        454298.0
# 2        517226.0
# 3       5772481.0
# 4      20502131.0
#           ...
# 115      952287.0
# 116     1545054.0
# 117     1367593.0
# 118     2135489.0
# 119     1083070.0
# Name: 봄배추 반입량, Length: 120, dtype: float64

# %%
SC.isnull().sum()
# Out:
# 0

# %%
df = df.drop(['봄배추 10.0 kg 상자 /중', '봄배추 10.0 kg 상자 /하','여름배추 10.0 kg 상자 /중','여름배추 10.0 kg 상자 /하','김장(가을)배추 10.0 kg 상자 /중','김장(가을)배추 10.0 kg 상자 /하','월동배추 10.0 kg 상자 /중','월동배추 10.0 kg 상자 /하'],axis=1)

# %%
df.isnull().sum()
# Out:
# 거래일자                        0
# 봄배추 10.0 kg 상자 /특          44
# 봄배추 10.0 kg 상자 /상          36
# 봄배추 반입량                     1
# 여름배추 10.0 kg 상자 /특         69
# 여름배추 10.0 kg 상자 /상          8
# 여름배추 반입량                    1
# 김장(가을)배추 10.0 kg 상자 /특     80
# 김장(가을)배추 10.0 kg 상자 /상     77
# 김장(가을)배추 반입량                6
# 월동배추 10.0 kg 상자 /특         11
# 월동배추 10.0 kg 상자 /상         20
# 월동배추 반입량                    1
# 고냉지배추 10.0 kg 상자 /특        66
# 고냉지배추 10.0 kg 상자 /상        92
# 고냉지배추 10.0 kg 상자 /중       109
# 고냉지배추 10.0 kg 상자 /하       118
# 고냉지배추 반입량                  17
# 저장배추 10.0 kg 상자 /특         96
# 저장배추 10.0 kg 상자 /상         93
# 저장배추 10.0 kg 상자 /중        115
# 저장배추 10.0 kg 상자 /하        119
# 저장배추 반입량                    2
# dtype: int64

# %%
df
# Out:
#            거래일자  봄배추 10.0 kg 상자 /특  봄배추 10.0 kg 상자 /상     봄배추 반입량  \
# 0    2021-01-11                NaN                NaN    416791.0
# 1    2021-02-11             1600.0                NaN    454298.0
# 2    2021-03-11             5878.0             6333.0    517226.0
# 3    2021-04-11             5709.0             4551.0   5772481.0
# 4    2021-05-11             3051.0             2040.0  20502131.0
# ..          ...                ...                ...         ...
# 116  2021-09-20            27171.0            22992.0   1545054.0
# 117  2021-10-20             9631.0             8675.0   1367593.0
# 118  2021-11-20             5893.0             4283.0   2135489.0
# 119  2021-12-20             4761.0             3458.0   1083070.0
# 120  2021-01-21                NaN                NaN         NaN
#
#      여름배추 10.0 kg 상자 /특  여름배추 10.0 kg 상자 /상   여름배추 반입량  \
# 0                   NaN              5966.0    54428.0
# 1                   NaN              4573.0    35492.0
# 2                   NaN              5183.0    40261.0
# 3                   NaN              4143.0    49221.0
# 4                   NaN              2299.0   107292.0
# ..                  ...                 ...        ...
# 116             19129.0             28806.0  6836961.0
# 117              7761.0             15724.0  3163670.0
# 118              4514.0             11002.0   143790.0
# 119                 NaN              8869.0    73494.0
# 120                 NaN                 NaN        NaN
#
#      김장(가을)배추 10.0 kg 상자 /특  김장(가을)배추 10.0 kg 상자 /상  김장(가을)배추 반입량  ...  \
# 0                   11000.0                  5133.0     1330758.0  ...
# 1                       NaN                     NaN      978786.0  ...
# 2                       NaN                     NaN     1038589.0  ...
# 3                       NaN                     NaN      350601.0  ...
# 4                       NaN                   688.0      373553.0  ...
# ..                      ...                     ...           ...  ...
# 116                     NaN                     NaN       12940.0  ...
# 117                  7440.0                  6521.0    12137940.0  ...
# 118                  4288.0                  3536.0    34610431.0  ...
# 119                     NaN                  3515.0    23680338.0  ...
# 120                     NaN                     NaN       26000.0  ...
#
#      고냉지배추 10.0 kg 상자 /특  고냉지배추 10.0 kg 상자 /상  고냉지배추 10.0 kg 상자 /중  \
# 0                    NaN                  NaN                  NaN
# 1                 6600.0               3650.0               3800.0
# 2                 5950.0               4350.0               4025.0
# 3                  775.0                400.0                  NaN
# 4                 1700.0               1100.0                800.0
# ..                   ...                  ...                  ...
# 116              14913.0              11877.0                  NaN
# 117               9376.0               7150.0               8900.0
# 118                  NaN                  NaN                  NaN
# 119                  NaN                  NaN                  NaN
# 120                  NaN                  NaN                  NaN
#
#      고냉지배추 10.0 kg 상자 /하   고냉지배추 반입량  저장배추 10.0 kg 상자 /특  저장배추 10.0 kg 상자 /상  \
# 0                    NaN   5316904.0                 NaN                 NaN
# 1                    NaN   6684087.0                 NaN                 NaN
# 2                    NaN   5786184.0              9799.0              5189.0
# 3                    NaN      6004.0              8345.0              4352.0
# 4                    NaN      6100.0              6457.0              3417.0
# ..                   ...         ...                 ...                 ...
# 116                  NaN  14708066.0                 NaN                 NaN
# 117               7000.0   1848253.0                 NaN                 NaN
# 118                  NaN       180.0                 NaN              4000.0
# 119                  NaN         NaN                 NaN                 NaN
# 120                  NaN         NaN                 NaN                 NaN
#
#      저장배추 10.0 kg 상자 /중  저장배추 10.0 kg 상자 /하    저장배추 반입량
# 0                   NaN                 NaN    375405.0
# 1                   NaN                 NaN    486980.0
# 2                3650.0                 NaN   4945713.0
# 3                3683.0                 NaN  14046697.0
# 4                   NaN               500.0   2326399.0
# ..                  ...                 ...         ...
# 116                 NaN                 NaN     81156.0
# 117                 NaN                 NaN    315876.0
# 118                 NaN                 NaN   1035532.0
# 119                 NaN                 NaN    182824.0
# 120                 NaN                 NaN         NaN
#
# [121 rows x 23 columns]

# %%
df = df.drop(['고냉지배추 10.0 kg 상자 /중', '고냉지배추 10.0 kg 상자 /하','저장배추 10.0 kg 상자 /중','저장배추 10.0 kg 상자 /하'],axis=1)

# %%
df
# Out:
#            거래일자  봄배추 10.0 kg 상자 /특  봄배추 10.0 kg 상자 /상     봄배추 반입량  \
# 0    2021-01-11                NaN                NaN    416791.0
# 1    2021-02-11             1600.0                NaN    454298.0
# 2    2021-03-11             5878.0             6333.0    517226.0
# 3    2021-04-11             5709.0             4551.0   5772481.0
# 4    2021-05-11             3051.0             2040.0  20502131.0
# ..          ...                ...                ...         ...
# 116  2021-09-20            27171.0            22992.0   1545054.0
# 117  2021-10-20             9631.0             8675.0   1367593.0
# 118  2021-11-20             5893.0             4283.0   2135489.0
# 119  2021-12-20             4761.0             3458.0   1083070.0
# 120  2021-01-21                NaN                NaN         NaN
#
#      여름배추 10.0 kg 상자 /특  여름배추 10.0 kg 상자 /상   여름배추 반입량  \
# 0                   NaN              5966.0    54428.0
# 1                   NaN              4573.0    35492.0
# 2                   NaN              5183.0    40261.0
# 3                   NaN              4143.0    49221.0
# 4                   NaN              2299.0   107292.0
# ..                  ...                 ...        ...
# 116             19129.0             28806.0  6836961.0
# 117              7761.0             15724.0  3163670.0
# 118              4514.0             11002.0   143790.0
# 119                 NaN              8869.0    73494.0
# 120                 NaN                 NaN        NaN
#
#      김장(가을)배추 10.0 kg 상자 /특  김장(가을)배추 10.0 kg 상자 /상  김장(가을)배추 반입량  \
# 0                   11000.0                  5133.0     1330758.0
# 1                       NaN                     NaN      978786.0
# 2                       NaN                     NaN     1038589.0
# 3                       NaN                     NaN      350601.0
# 4                       NaN                   688.0      373553.0
# ..                      ...                     ...           ...
# 116                     NaN                     NaN       12940.0
# 117                  7440.0                  6521.0    12137940.0
# 118                  4288.0                  3536.0    34610431.0
# 119                     NaN                  3515.0    23680338.0
# 120                     NaN                     NaN       26000.0
#
#      월동배추 10.0 kg 상자 /특  월동배추 10.0 kg 상자 /상   월동배추 반입량  고냉지배추 10.0 kg 상자 /특  \
# 0                5780.0              9437.0  5077825.0                  NaN
# 1               23758.0              7684.0  4754116.0               6600.0
# 2                6558.0              7616.0  6395515.0               5950.0
# 3                5328.0              3722.0  3429101.0                775.0
# 4                2014.0              1393.0  1430692.0               1700.0
# ..                  ...                 ...        ...                  ...
# 116             19100.0             12867.0  2577761.0              14913.0
# 117              7673.0              6867.0  2630720.0               9376.0
# 118              6016.0              5007.0  5910256.0                  NaN
# 119                 NaN                 NaN  2132084.0                  NaN
# 120                 NaN                 NaN        NaN                  NaN
#
#      고냉지배추 10.0 kg 상자 /상   고냉지배추 반입량  저장배추 10.0 kg 상자 /특  저장배추 10.0 kg 상자 /상  \
# 0                    NaN   5316904.0                 NaN                 NaN
# 1                 3650.0   6684087.0                 NaN                 NaN
# 2                 4350.0   5786184.0              9799.0              5189.0
# 3                  400.0      6004.0              8345.0              4352.0
# 4                 1100.0      6100.0              6457.0              3417.0
# ..                   ...         ...                 ...                 ...
# 116              11877.0  14708066.0                 NaN                 NaN
# 117               7150.0   1848253.0                 NaN                 NaN
# 118                  NaN       180.0                 NaN              4000.0
# 119                  NaN         NaN                 NaN                 NaN
# 120                  NaN         NaN                 NaN                 NaN
#
#        저장배추 반입량
# 0      375405.0
# 1      486980.0
# 2     4945713.0
# 3    14046697.0
# 4     2326399.0
# ..          ...
# 116     81156.0
# 117    315876.0
# 118   1035532.0
# 119    182824.0
# 120         NaN
#
# [121 rows x 19 columns]

# %%
################################################################ 여기 보류
df_thresh = df.dropna(axis = 1, thresh = 80)
df_thresh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   거래일자                121 non-null    object
#  1   봄배추 10.0 kg 상자 /상   85 non-null     float64
#  2   봄배추 반입량             120 non-null    float64
#  3   여름배추 10.0 kg 상자 /상  113 non-null    float64
#  4   여름배추 반입량            120 non-null    float64
#  5   김장(가을)배추 반입량        115 non-null    float64
#  6   월동배추 10.0 kg 상자 /특  110 non-null    float64
#  7   월동배추 10.0 kg 상자 /상  101 non-null    float64
#  8   월동배추 반입량            120 non-null    float64
#  9   고냉지배추 반입량           104 non-null    float64
#  10  저장배추 반입량            119 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 10.5+ KB

# %%
df = df.drop([120])   ##### 마지막 행 삭제

# %%
df
# Out:
#            거래일자  봄배추 10.0 kg 상자 /특  봄배추 10.0 kg 상자 /상     봄배추 반입량  \
# 0    2011-01-01                NaN                NaN    416791.0
# 1    2011-02-01             1600.0                NaN    454298.0
# 2    2011-03-01             5878.0             6333.0    517226.0
# 3    2011-04-01             5709.0             4551.0   5772481.0
# 4    2011-05-01             3051.0             2040.0  20502131.0
# ..          ...                ...                ...         ...
# 115  2020-08-01            17176.0            10786.0    952287.0
# 116  2020-09-01            27171.0            22992.0   1545054.0
# 117  2020-10-01             9631.0             8675.0   1367593.0
# 118  2020-11-01             5893.0             4283.0   2135489.0
# 119  2020-12-01             4761.0             3458.0   1083070.0
#
#      여름배추 10.0 kg 상자 /특  여름배추 10.0 kg 상자 /상   여름배추 반입량  \
# 0                   NaN              5966.0    54428.0
# 1                   NaN              4573.0    35492.0
# 2                   NaN              5183.0    40261.0
# 3                   NaN              4143.0    49221.0
# 4                   NaN              2299.0   107292.0
# ..                  ...                 ...        ...
# 115             15278.0             17359.0  6099132.0
# 116             19129.0             28806.0  6836961.0
# 117              7761.0             15724.0  3163670.0
# 118              4514.0             11002.0   143790.0
# 119                 NaN              8869.0    73494.0
#
#      김장(가을)배추 10.0 kg 상자 /특  김장(가을)배추 10.0 kg 상자 /상  김장(가을)배추 반입량  \
# 0                   11000.0                  5133.0     1330758.0
# 1                       NaN                     NaN      978786.0
# 2                       NaN                     NaN     1038589.0
# 3                       NaN                     NaN      350601.0
# 4                       NaN                   688.0      373553.0
# ..                      ...                     ...           ...
# 115                     NaN                     NaN        3140.0
# 116                     NaN                     NaN       12940.0
# 117                  7440.0                  6521.0    12137940.0
# 118                  4288.0                  3536.0    34610431.0
# 119                     NaN                  3515.0    23680338.0
#
#      월동배추 10.0 kg 상자 /특  월동배추 10.0 kg 상자 /상   월동배추 반입량  고냉지배추 10.0 kg 상자 /특  \
# 0                5780.0              9437.0  5077825.0                  NaN
# 1               23758.0              7684.0  4754116.0               6600.0
# 2                6558.0              7616.0  6395515.0               5950.0
# 3                5328.0              3722.0  3429101.0                775.0
# 4                2014.0              1393.0  1430692.0               1700.0
# ..                  ...                 ...        ...                  ...
# 115             11914.0              9843.0  1868148.0              19274.0
# 116             19100.0             12867.0  2577761.0              14913.0
# 117              7673.0              6867.0  2630720.0               9376.0
# 118              6016.0              5007.0  5910256.0                  NaN
# 119                 NaN                 NaN  2132084.0                  NaN
#
#      고냉지배추 10.0 kg 상자 /상   고냉지배추 반입량  저장배추 10.0 kg 상자 /특  저장배추 10.0 kg 상자 /상  \
# 0                    NaN   5316904.0                 NaN                 NaN
# 1                 3650.0   6684087.0                 NaN                 NaN
# 2                 4350.0   5786184.0              9799.0              5189.0
# 3                  400.0      6004.0              8345.0              4352.0
# 4                 1100.0      6100.0              6457.0              3417.0
# ..                   ...         ...                 ...                 ...
# 115              12625.0   6629065.0                 NaN             10300.0
# 116              11877.0  14708066.0                 NaN                 NaN
# 117               7150.0   1848253.0                 NaN                 NaN
# 118                  NaN       180.0                 NaN              4000.0
# 119                  NaN         NaN                 NaN                 NaN
#
#        저장배추 반입량
# 0      375405.0
# 1      486980.0
# 2     4945713.0
# 3    14046697.0
# 4     2326399.0
# ..          ...
# 115    115612.0
# 116     81156.0
# 117    315876.0
# 118   1035532.0
# 119    182824.0
#
# [120 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# 거래일자                       0
# 봄배추 10.0 kg 상자 /특         43
# 봄배추 10.0 kg 상자 /상         35
# 봄배추 반입량                    0
# 여름배추 10.0 kg 상자 /특        68
# 여름배추 10.0 kg 상자 /상         7
# 여름배추 반입량                   0
# 김장(가을)배추 10.0 kg 상자 /특    79
# 김장(가을)배추 10.0 kg 상자 /상    76
# 김장(가을)배추 반입량               6
# 월동배추 10.0 kg 상자 /특        10
# 월동배추 10.0 kg 상자 /상        19
# 월동배추 반입량                   0
# 고냉지배추 10.0 kg 상자 /특       65
# 고냉지배추 10.0 kg 상자 /상       91
# 고냉지배추 반입량                 16
# 저장배추 10.0 kg 상자 /특        95
# 저장배추 10.0 kg 상자 /상        92
# 저장배추 반입량                   1
# dtype: int64

# %%
df = df.drop(['고냉지배추 10.0 kg 상자 /특', '고냉지배추 10.0 kg 상자 /상','저장배추 10.0 kg 상자 /특','저장배추 10.0 kg 상자 /상','고냉지배추 반입량','저장배추 반입량'],axis=1)

# %%
df
# Out:
#            거래일자  봄배추 10.0 kg 상자 /특  봄배추 10.0 kg 상자 /상     봄배추 반입량  \
# 0    2021-01-11                NaN                NaN    416791.0
# 1    2021-02-11             1600.0                NaN    454298.0
# 2    2021-03-11             5878.0             6333.0    517226.0
# 3    2021-04-11             5709.0             4551.0   5772481.0
# 4    2021-05-11             3051.0             2040.0  20502131.0
# ..          ...                ...                ...         ...
# 115  2021-08-20            17176.0            10786.0    952287.0
# 116  2021-09-20            27171.0            22992.0   1545054.0
# 117  2021-10-20             9631.0             8675.0   1367593.0
# 118  2021-11-20             5893.0             4283.0   2135489.0
# 119  2021-12-20             4761.0             3458.0   1083070.0
#
#      여름배추 10.0 kg 상자 /특  여름배추 10.0 kg 상자 /상   여름배추 반입량  \
# 0                   NaN              5966.0    54428.0
# 1                   NaN              4573.0    35492.0
# 2                   NaN              5183.0    40261.0
# 3                   NaN              4143.0    49221.0
# 4                   NaN              2299.0   107292.0
# ..                  ...                 ...        ...
# 115             15278.0             17359.0  6099132.0
# 116             19129.0             28806.0  6836961.0
# 117              7761.0             15724.0  3163670.0
# 118              4514.0             11002.0   143790.0
# 119                 NaN              8869.0    73494.0
#
#      김장(가을)배추 10.0 kg 상자 /특  김장(가을)배추 10.0 kg 상자 /상  김장(가을)배추 반입량  \
# 0                   11000.0                  5133.0     1330758.0
# 1                       NaN                     NaN      978786.0
# 2                       NaN                     NaN     1038589.0
# 3                       NaN                     NaN      350601.0
# 4                       NaN                   688.0      373553.0
# ..                      ...                     ...           ...
# 115                     NaN                     NaN        3140.0
# 116                     NaN                     NaN       12940.0
# 117                  7440.0                  6521.0    12137940.0
# 118                  4288.0                  3536.0    34610431.0
# 119                     NaN                  3515.0    23680338.0
#
#      월동배추 10.0 kg 상자 /특  월동배추 10.0 kg 상자 /상   월동배추 반입량
# 0                5780.0              9437.0  5077825.0
# 1               23758.0              7684.0  4754116.0
# 2                6558.0              7616.0  6395515.0
# 3                5328.0              3722.0  3429101.0
# 4                2014.0              1393.0  1430692.0
# ..                  ...                 ...        ...
# 115             11914.0              9843.0  1868148.0
# 116             19100.0             12867.0  2577761.0
# 117              7673.0              6867.0  2630720.0
# 118              6016.0              5007.0  5910256.0
# 119                 NaN                 NaN  2132084.0
#
# [120 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# 거래일자                       0
# 봄배추 10.0 kg 상자 /특         43
# 봄배추 10.0 kg 상자 /상         35
# 봄배추 반입량                    0
# 여름배추 10.0 kg 상자 /특        68
# 여름배추 10.0 kg 상자 /상         7
# 여름배추 반입량                   0
# 김장(가을)배추 10.0 kg 상자 /특    79
# 김장(가을)배추 10.0 kg 상자 /상    76
# 김장(가을)배추 반입량               6
# 월동배추 10.0 kg 상자 /특        10
# 월동배추 10.0 kg 상자 /상        19
# 월동배추 반입량                   0
# dtype: int64

# %%
df = df.dropna(subset=["김장(가을)배추 반입량"])

# %%
df.isnull().sum()
# Out:
# 거래일자                       0
# 봄배추 10.0 kg 상자 /특         43
# 봄배추 10.0 kg 상자 /상         35
# 봄배추 반입량                    0
# 여름배추 10.0 kg 상자 /특        66
# 여름배추 10.0 kg 상자 /상         7
# 여름배추 반입량                   0
# 김장(가을)배추 10.0 kg 상자 /특    73
# 김장(가을)배추 10.0 kg 상자 /상    70
# 김장(가을)배추 반입량               0
# 월동배추 10.0 kg 상자 /특        10
# 월동배추 10.0 kg 상자 /상        17
# 월동배추 반입량                   0
# dtype: int64

# %%
df = df.drop(['봄배추 10.0 kg 상자 /특', '여름배추 10.0 kg 상자 /특','김장(가을)배추 10.0 kg 상자 /특','월동배추 10.0 kg 상자 /상'],axis=1)

# %%
df.isnull().sum()
# Out:
# 거래일자                       0
# 봄배추 10.0 kg 상자 /상         35
# 봄배추 반입량                    0
# 여름배추 10.0 kg 상자 /상         7
# 여름배추 반입량                   0
# 김장(가을)배추 10.0 kg 상자 /상    70
# 김장(가을)배추 반입량               0
# 월동배추 10.0 kg 상자 /특        10
# 월동배추 반입량                   0
# dtype: int64

# %%
df
# Out:
#            거래일자  봄배추 10.0 kg 상자 /상     봄배추 반입량  여름배추 10.0 kg 상자 /상   여름배추 반입량  \
# 0    2011-01-01                NaN    416791.0              5966.0    54428.0
# 1    2011-02-01                NaN    454298.0              4573.0    35492.0
# 2    2011-03-01             6333.0    517226.0              5183.0    40261.0
# 3    2011-04-01             4551.0   5772481.0              4143.0    49221.0
# 4    2011-05-01             2040.0  20502131.0              2299.0   107292.0
# ..          ...                ...         ...                 ...        ...
# 115  2020-08-01            10786.0    952287.0             17359.0  6099132.0
# 116  2020-09-01            22992.0   1545054.0             28806.0  6836961.0
# 117  2020-10-01             8675.0   1367593.0             15724.0  3163670.0
# 118  2020-11-01             4283.0   2135489.0             11002.0   143790.0
# 119  2020-12-01             3458.0   1083070.0              8869.0    73494.0
#
#      김장(가을)배추 10.0 kg 상자 /상  김장(가을)배추 반입량  월동배추 10.0 kg 상자 /특   월동배추 반입량
# 0                    5133.0     1330758.0              5780.0  5077825.0
# 1                       NaN      978786.0             23758.0  4754116.0
# 2                       NaN     1038589.0              6558.0  6395515.0
# 3                       NaN      350601.0              5328.0  3429101.0
# 4                     688.0      373553.0              2014.0  1430692.0
# ..                      ...           ...                 ...        ...
# 115                     NaN        3140.0             11914.0  1868148.0
# 116                     NaN       12940.0             19100.0  2577761.0
# 117                  6521.0    12137940.0              7673.0  2630720.0
# 118                  3536.0    34610431.0              6016.0  5910256.0
# 119                  3515.0    23680338.0                 NaN  2132084.0
#
# [114 rows x 9 columns]

# %%
df = df.dropna(subset=["여름배추 10.0 kg 상자 /상"])

# %%
df.isnull().sum()
# Out:
# 거래일자                       0
# 봄배추 10.0 kg 상자 /상         35
# 봄배추 반입량                    0
# 여름배추 10.0 kg 상자 /상         0
# 여름배추 반입량                   0
# 김장(가을)배추 10.0 kg 상자 /상    64
# 김장(가을)배추 반입량               0
# 월동배추 10.0 kg 상자 /특         9
# 월동배추 반입량                   0
# dtype: int64

# %%
df
# Out:
#            거래일자  봄배추 10.0 kg 상자 /상     봄배추 반입량  여름배추 10.0 kg 상자 /상   여름배추 반입량  \
# 0    2021-01-11                NaN    416791.0              5966.0    54428.0
# 1    2021-02-11                NaN    454298.0              4573.0    35492.0
# 2    2021-03-11             6333.0    517226.0              5183.0    40261.0
# 3    2021-04-11             4551.0   5772481.0              4143.0    49221.0
# 4    2021-05-11             2040.0  20502131.0              2299.0   107292.0
# ..          ...                ...         ...                 ...        ...
# 115  2021-08-20            10786.0    952287.0             17359.0  6099132.0
# 116  2021-09-20            22992.0   1545054.0             28806.0  6836961.0
# 117  2021-10-20             8675.0   1367593.0             15724.0  3163670.0
# 118  2021-11-20             4283.0   2135489.0             11002.0   143790.0
# 119  2021-12-20             3458.0   1083070.0              8869.0    73494.0
#
#      김장(가을)배추 10.0 kg 상자 /상  김장(가을)배추 반입량  월동배추 10.0 kg 상자 /특   월동배추 반입량
# 0                    5133.0     1330758.0              5780.0  5077825.0
# 1                       NaN      978786.0             23758.0  4754116.0
# 2                       NaN     1038589.0              6558.0  6395515.0
# 3                       NaN      350601.0              5328.0  3429101.0
# 4                     688.0      373553.0              2014.0  1430692.0
# ..                      ...           ...                 ...        ...
# 115                     NaN        3140.0             11914.0  1868148.0
# 116                     NaN       12940.0             19100.0  2577761.0
# 117                  6521.0    12137940.0              7673.0  2630720.0
# 118                  3536.0    34610431.0              6016.0  5910256.0
# 119                  3515.0    23680338.0                 NaN  2132084.0
#
# [107 rows x 9 columns]

# %%
df = df.dropna(subset=["월동배추 10.0 kg 상자 /특"])

# %%
df.isnull().sum()
# Out:
# 거래일자                       0
# 봄배추 10.0 kg 상자 /상         32
# 봄배추 반입량                    0
# 여름배추 10.0 kg 상자 /상         0
# 여름배추 반입량                   0
# 김장(가을)배추 10.0 kg 상자 /상    57
# 김장(가을)배추 반입량               0
# 월동배추 10.0 kg 상자 /특         0
# 월동배추 반입량                   0
# dtype: int64

# %%
df
# Out:
#            거래일자  봄배추 10.0 kg 상자 /상     봄배추 반입량  여름배추 10.0 kg 상자 /상  \
# 0    2011-01-01                NaN    416791.0              5966.0
# 1    2011-02-01                NaN    454298.0              4573.0
# 2    2011-03-01             6333.0    517226.0              5183.0
# 3    2011-04-01             4551.0   5772481.0              4143.0
# 4    2011-05-01             2040.0  20502131.0              2299.0
# ..          ...                ...         ...                 ...
# 114  2020-07-01             6930.0   1702178.0              8965.0
# 115  2020-08-01            10786.0    952287.0             17359.0
# 116  2020-09-01            22992.0   1545054.0             28806.0
# 117  2020-10-01             8675.0   1367593.0             15724.0
# 118  2020-11-01             4283.0   2135489.0             11002.0
#
#        여름배추 반입량  김장(가을)배추 10.0 kg 상자 /상  김장(가을)배추 반입량  월동배추 10.0 kg 상자 /특  \
# 0       54428.0                  5133.0     1330758.0              5780.0
# 1       35492.0                     NaN      978786.0             23758.0
# 2       40261.0                     NaN     1038589.0              6558.0
# 3       49221.0                     NaN      350601.0              5328.0
# 4      107292.0                   688.0      373553.0              2014.0
# ..          ...                     ...           ...                 ...
# 114  13222219.0                     NaN        9060.0              8850.0
# 115   6099132.0                     NaN        3140.0             11914.0
# 116   6836961.0                     NaN       12940.0             19100.0
# 117   3163670.0                  6521.0    12137940.0              7673.0
# 118    143790.0                  3536.0    34610431.0              6016.0
#
#       월동배추 반입량
# 0    5077825.0
# 1    4754116.0
# 2    6395515.0
# 3    3429101.0
# 4    1430692.0
# ..         ...
# 114  1861942.0
# 115  1868148.0
# 116  2577761.0
# 117  2630720.0
# 118  5910256.0
#
# [98 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# 거래일자                       0
# 봄배추 10.0 kg 상자 /상         32
# 봄배추 반입량                    0
# 여름배추 10.0 kg 상자 /상         0
# 여름배추 반입량                   0
# 김장(가을)배추 10.0 kg 상자 /상    57
# 김장(가을)배추 반입량               0
# 월동배추 10.0 kg 상자 /특         0
# 월동배추 반입량                   0
# dtype: int64

# %%
df
# Out:
#            거래일자  봄배추 10.0 kg 상자 /상     봄배추 반입량  여름배추 10.0 kg 상자 /상  \
# 0    2011-01-01                NaN    416791.0              5966.0
# 1    2011-02-01                NaN    454298.0              4573.0
# 2    2011-03-01             6333.0    517226.0              5183.0
# 3    2011-04-01             4551.0   5772481.0              4143.0
# 4    2011-05-01             2040.0  20502131.0              2299.0
# ..          ...                ...         ...                 ...
# 114  2020-07-01             6930.0   1702178.0              8965.0
# 115  2020-08-01            10786.0    952287.0             17359.0
# 116  2020-09-01            22992.0   1545054.0             28806.0
# 117  2020-10-01             8675.0   1367593.0             15724.0
# 118  2020-11-01             4283.0   2135489.0             11002.0
#
#        여름배추 반입량  김장(가을)배추 10.0 kg 상자 /상  김장(가을)배추 반입량  월동배추 10.0 kg 상자 /특  \
# 0       54428.0                  5133.0     1330758.0              5780.0
# 1       35492.0                     NaN      978786.0             23758.0
# 2       40261.0                     NaN     1038589.0              6558.0
# 3       49221.0                     NaN      350601.0              5328.0
# 4      107292.0                   688.0      373553.0              2014.0
# ..          ...                     ...           ...                 ...
# 114  13222219.0                     NaN        9060.0              8850.0
# 115   6099132.0                     NaN        3140.0             11914.0
# 116   6836961.0                     NaN       12940.0             19100.0
# 117   3163670.0                  6521.0    12137940.0              7673.0
# 118    143790.0                  3536.0    34610431.0              6016.0
#
#       월동배추 반입량
# 0    5077825.0
# 1    4754116.0
# 2    6395515.0
# 3    3429101.0
# 4    1430692.0
# ..         ...
# 114  1861942.0
# 115  1868148.0
# 116  2577761.0
# 117  2630720.0
# 118  5910256.0
#
# [98 rows x 9 columns]

# %%
df = df.fillna(0)

# %%
df
# Out:
#            거래일자  봄배추 10.0 kg 상자 /상     봄배추 반입량  여름배추 10.0 kg 상자 /상  \
# 0    2011-01-01                0.0    416791.0              5966.0
# 1    2011-02-01                0.0    454298.0              4573.0
# 2    2011-03-01             6333.0    517226.0              5183.0
# 3    2011-04-01             4551.0   5772481.0              4143.0
# 4    2011-05-01             2040.0  20502131.0              2299.0
# ..          ...                ...         ...                 ...
# 114  2020-07-01             6930.0   1702178.0              8965.0
# 115  2020-08-01            10786.0    952287.0             17359.0
# 116  2020-09-01            22992.0   1545054.0             28806.0
# 117  2020-10-01             8675.0   1367593.0             15724.0
# 118  2020-11-01             4283.0   2135489.0             11002.0
#
#        여름배추 반입량  김장(가을)배추 10.0 kg 상자 /상  김장(가을)배추 반입량  월동배추 10.0 kg 상자 /특  \
# 0       54428.0                  5133.0     1330758.0              5780.0
# 1       35492.0                     0.0      978786.0             23758.0
# 2       40261.0                     0.0     1038589.0              6558.0
# 3       49221.0                     0.0      350601.0              5328.0
# 4      107292.0                   688.0      373553.0              2014.0
# ..          ...                     ...           ...                 ...
# 114  13222219.0                     0.0        9060.0              8850.0
# 115   6099132.0                     0.0        3140.0             11914.0
# 116   6836961.0                     0.0       12940.0             19100.0
# 117   3163670.0                  6521.0    12137940.0              7673.0
# 118    143790.0                  3536.0    34610431.0              6016.0
#
#       월동배추 반입량
# 0    5077825.0
# 1    4754116.0
# 2    6395515.0
# 3    3429101.0
# 4    1430692.0
# ..         ...
# 114  1861942.0
# 115  1868148.0
# 116  2577761.0
# 117  2630720.0
# 118  5910256.0
#
# [98 rows x 9 columns]

# %%
df = df.drop(['가격'],axis=1)

# %%
df['가격'] = (df['봄배추 10.0 kg 상자 /상'] + df['여름배추 10.0 kg 상자 /상'] + df['김장(가을)배추 10.0 kg 상자 /상'] + df['월동배추 10.0 kg 상자 /특'])/4

# %%
df
# Out:
#            거래일자  봄배추 10.0 kg 상자 /상     봄배추 반입량  여름배추 10.0 kg 상자 /상  \
# 0    2011-01-01                0.0    416791.0              5966.0
# 1    2011-02-01                0.0    454298.0              4573.0
# 2    2011-03-01             6333.0    517226.0              5183.0
# 3    2011-04-01             4551.0   5772481.0              4143.0
# 4    2011-05-01             2040.0  20502131.0              2299.0
# ..          ...                ...         ...                 ...
# 114  2020-07-01             6930.0   1702178.0              8965.0
# 115  2020-08-01            10786.0    952287.0             17359.0
# 116  2020-09-01            22992.0   1545054.0             28806.0
# 117  2020-10-01             8675.0   1367593.0             15724.0
# 118  2020-11-01             4283.0   2135489.0             11002.0
#
#        여름배추 반입량  김장(가을)배추 10.0 kg 상자 /상  김장(가을)배추 반입량  월동배추 10.0 kg 상자 /특  \
# 0       54428.0                  5133.0     1330758.0              5780.0
# 1       35492.0                     0.0      978786.0             23758.0
# 2       40261.0                     0.0     1038589.0              6558.0
# 3       49221.0                     0.0      350601.0              5328.0
# 4      107292.0                   688.0      373553.0              2014.0
# ..          ...                     ...           ...                 ...
# 114  13222219.0                     0.0        9060.0              8850.0
# 115   6099132.0                     0.0        3140.0             11914.0
# 116   6836961.0                     0.0       12940.0             19100.0
# 117   3163670.0                  6521.0    12137940.0              7673.0
# 118    143790.0                  3536.0    34610431.0              6016.0
#
#       월동배추 반입량        가격
# 0    5077825.0   4219.75
# 1    4754116.0   7082.75
# 2    6395515.0   4518.50
# 3    3429101.0   3505.50
# 4    1430692.0   1760.25
# ..         ...       ...
# 114  1861942.0   6186.25
# 115  1868148.0  10014.75
# 116  2577761.0  17724.50
# 117  2630720.0   9648.25
# 118  5910256.0   6209.25
#
# [98 rows x 10 columns]

# %%
df = df.drop(['봄배추 10.0 kg 상자 /상', '여름배추 10.0 kg 상자 /상','김장(가을)배추 10.0 kg 상자 /상','월동배추 10.0 kg 상자 /특'],axis=1)

# %%
df
# Out:
#            거래일자     봄배추 반입량    여름배추 반입량  김장(가을)배추 반입량   월동배추 반입량        가격
# 0    2021-01-11    416791.0     54428.0     1330758.0  5077825.0   4219.75
# 1    2021-02-11    454298.0     35492.0      978786.0  4754116.0   7082.75
# 2    2021-03-11    517226.0     40261.0     1038589.0  6395515.0   4518.50
# 3    2021-04-11   5772481.0     49221.0      350601.0  3429101.0   3505.50
# 4    2021-05-11  20502131.0    107292.0      373553.0  1430692.0   1760.25
# ..          ...         ...         ...           ...        ...       ...
# 114  2021-07-20   1702178.0  13222219.0        9060.0  1861942.0   6186.25
# 115  2021-08-20    952287.0   6099132.0        3140.0  1868148.0  10014.75
# 116  2021-09-20   1545054.0   6836961.0       12940.0  2577761.0  17724.50
# 117  2021-10-20   1367593.0   3163670.0    12137940.0  2630720.0   9648.25
# 118  2021-11-20   2135489.0    143790.0    34610431.0  5910256.0   6209.25
#
# [98 rows x 6 columns]

# %%
df['가격'].describe()
# Out:
# count       98.00000
# mean      5235.32398
# std       2556.27752
# min       1635.75000
# 25%       3314.43750
# 50%       4600.50000
# 75%       6487.50000
# max      17724.50000
# Name: 가격, dtype: float64

# %%
df['가격'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(df['가격'])
plt.show()

# %%
numerical_columns=['봄배추 반입량', '여름배추 반입량', '김장(가을)배추 반입량', '월동배추 반입량']
fig = plt.figure(figsize = (16, 20))
ax = fig.gca()
df[numerical_columns].hist(ax=ax)
plt.show()
# Out:
# <ipython-input-95-06764367d2f2>:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df[numerical_columns].hist(ax=ax)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48388 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47492 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44608 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51012 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48388 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47492 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44608 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51012 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
cols = ['가격','봄배추 반입량', '여름배추 반입량', '김장(가을)배추 반입량', '월동배추 반입량']

corr = df[cols].corr(method = 'pearson')
corr
# Out:
#                     가격   봄배추 반입량  여름배추 반입량  김장(가을)배추 반입량  월동배추 반입량
# 가격            1.000000 -0.117282  0.107748      0.000717 -0.166039
# 봄배추 반입량      -0.117282  1.000000 -0.165504     -0.201773 -0.317410
# 여름배추 반입량      0.107748 -0.165504  1.000000     -0.260344 -0.349957
# 김장(가을)배추 반입량  0.000717 -0.201773 -0.260344      1.000000  0.001449
# 월동배추 반입량     -0.166039 -0.317410 -0.349957      0.001449  1.000000

# %%
fig = plt.figure(figsize = (16, 12))
ax = fig.gca()
sns.set(font_scale = 1.5)  # heatmap 안의 font-size 설정 
heatmap = sns.heatmap(corr.values, annot = True, fmt='.2f', annot_kws={'size':15},
                      yticklabels = cols, xticklabels = cols, ax=ax, cmap = "RdYlBu")
plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48388 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47492 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44608 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51012 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48388 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47492 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44608 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51012 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.scatterplot(data=df, x='봄배추 반입량', y='가격', markers='o', color='blue', alpha=0.6)
plt.title('Scatter Plot')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48388 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48388 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.scatterplot(data=df, x='여름배추 반입량', y='가격', markers='o', color='blue', alpha=0.6)
plt.title('Scatter Plot')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47492 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47492 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()  # 평균 0, 표준편차 1
scale_columns = ['봄배추 반입량', '여름배추 반입량', '김장(가을)배추 반입량', '월동배추 반입량']
df[scale_columns] = scaler.fit_transform(df[scale_columns])

# %%
df.head()
# Out:
#          거래일자   봄배추 반입량  여름배추 반입량  김장(가을)배추 반입량  월동배추 반입량       가격
# 0  2021-01-11 -0.504223 -0.546712     -0.512769  0.063917  4219.75
# 1  2021-02-11 -0.498271 -0.550317     -0.540178 -0.010509  7082.75
# 2  2021-03-11 -0.488285 -0.549409     -0.535521  0.366874  4518.50
# 3  2021-04-11  0.345640 -0.547703     -0.589095 -0.315150  3505.50
# 4  2021-05-11  2.683002 -0.536649     -0.587308 -0.774616  1760.25

# %%
df[numerical_columns].head()
# Out:
#     봄배추 반입량  여름배추 반입량  김장(가을)배추 반입량  월동배추 반입량
# 0 -0.504223 -0.546712     -0.512769  0.063917
# 1 -0.498271 -0.550317     -0.540178 -0.010509
# 2 -0.488285 -0.549409     -0.535521  0.366874
# 3  0.345640 -0.547703     -0.589095 -0.315150
# 4  2.683002 -0.536649     -0.587308 -0.774616

# %%
from sklearn.model_selection import train_test_split

# split dataset into training & test
X = df[numerical_columns]
y = df['가격']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train.shape, y_train.shape
# Out:
# ((78, 4), (78,))

# %%
X_test.shape, y_test.shape
# Out:
# ((20, 4), (20,))

# %%
y_train
# Out:
# 2     4518.50
# 44    4611.50
# 62    7540.25
# 57    3237.50
# 20    6529.75
#        ...
# 82    4693.25
# 9     4184.75
# 78    5419.00
# 12    2392.25
# 41    3290.50
# Name: 가격, Length: 78, dtype: float64

# %%
X_train
# Out:
#      봄배추 반입량  여름배추 반입량  김장(가을)배추 반입량  월동배추 반입량
# 2  -0.488285 -0.549409     -0.535521  0.366874
# 44 -0.453091  0.961613     -0.586350 -0.692067
# 62 -0.336500 -0.554772     -0.513972  0.833645
# 57 -0.146180 -0.086698      1.125176 -0.608496
# 20 -0.474153  0.906037     -0.535505 -0.691069
# ..       ...       ...           ...       ...
# 82 -0.530673 -0.540048      2.101499  0.484151
# 9  -0.423938  0.135931     -0.134699  2.794169
# 78 -0.301249  1.853231     -0.572599 -0.751620
# 12 -0.515169 -0.551105     -0.507866  0.135654
# 41  0.751730 -0.512852     -0.530989 -0.854512
#
# [78 rows x 4 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['features'] = X_train.columns
vif["VIF Factor"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif.round(1) 
### 소수점 첫째자리까지 표시합니다. 즉, 소수점 둘째짜리에서 반올림 합니다.
# Out:
#        features  VIF Factor
# 0       봄배추 반입량         1.4
# 1      여름배추 반입량         1.5
# 2  김장(가을)배추 반입량         1.2
# 3      월동배추 반입량         1.5

# %%
from sklearn import linear_model

# fit regression model in training set
lr = linear_model.LinearRegression()
model = lr.fit(X_train, y_train)

# predict in test set
pred_test = lr.predict(X_test)

# %%
### print coef 
### 계수를 출력합니다.
print(lr.coef_)
# Out:
# [-454.77357865  307.31966707 -110.75986862 -355.06850229]

# %%
coefs = pd.DataFrame(zip(df[numerical_columns].columns, lr.coef_), columns = ['feature', 'coefficients'])
coefs
# Out:
#         feature  coefficients
# 0       봄배추 반입량   -454.773579
# 1      여름배추 반입량    307.319667
# 2  김장(가을)배추 반입량   -110.759869
# 3      월동배추 반입량   -355.068502

# %%
coefs_new = coefs.reindex(coefs.coefficients.abs().sort_values(ascending=False).index)
coefs_new
# Out:
#         feature  coefficients
# 0       봄배추 반입량   -454.773579
# 3      월동배추 반입량   -355.068502
# 1      여름배추 반입량    307.319667
# 2  김장(가을)배추 반입량   -110.759869

# %%
### coefficients 를 시각화 합니다. 

### figure size
plt.figure(figsize = (8, 8))

### bar plot : matplotlib.pyplot 모듈의 barh() 함수를 사용해서 수평 막대 그래프를 그릴 수 있습니다. 
plt.barh(coefs_new['feature'], coefs_new['coefficients'])
plt.title('"feature - coefficient" Graph')
plt.xlabel('coefficients')
plt.ylabel('features')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48388 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47492 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44608 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51012 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48388 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48176 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47492 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44608 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51012 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import statsmodels.api as sm

X_train2 = sm.add_constant(X_train)
### 회귀분석모형 수식을 간단하게 만들기 위해 다음과 같이 상수항을 독립변수 데이터에 추가하는 것을 상수항 결합(bias augmentation)작업이라고 합니다.
### ordinary least square 의 약자로, 거리의 최소값을 기준으로 구하는 함수입니다. 

model2 = sm.OLS(y_train, X_train2).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     가격   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     1.289
# Date:                Tue, 02 Nov 2021   Prob (F-statistic):              0.282
# Time:                        22:57:01   Log-Likelihood:                -721.26
# No. Observations:                  78   AIC:                             1453.
# Df Residuals:                      73   BIC:                             1464.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         5272.4439    296.281     17.795      0.000    4681.956    5862.931
# 봄배추 반입량       -454.7736    328.591     -1.384      0.171   -1109.654     200.107
# 여름배추 반입량       307.3197    355.209      0.865      0.390    -400.610    1015.249
# 김장(가을)배추 반입량  -110.7599    320.970     -0.345      0.731    -750.453     528.933
# 월동배추 반입량      -355.0685    415.197     -0.855      0.395   -1182.554     472.417
# ==============================================================================
# Omnibus:                       42.446   Durbin-Watson:                   2.171
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              122.758
# Skew:                           1.792   Prob(JB):                     2.21e-27
# Kurtosis:                       7.993   Cond. No.                         2.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
### 예측 결과 시각화 (test set)
df = pd.DataFrame({'actual': y_test, 'prediction': pred_test})
df = df.sort_values(by='actual').reset_index(drop=True)
df.head()

### reset_index() : 아무래도 데이터프레임의 다양한 전처리 과정을 거치게 되면 인덱스가 뒤죽박죽인 경우가 많다. 이럴때 인덱스를 다시 처음부터 재배열 해주는 유용한 함수다.
### drop=True옵션을 주면 기존 인덱스를 버리고 재배열해준다.
### https://yganalyst.github.io/data_handling/Pd_2/
# Out:
#     actual   prediction
# 0  1819.00  3656.887168
# 1  2615.25  6540.875969
# 2  2658.50  5890.054123
# 3  2891.50  5230.487255
# 4  3000.25  4628.698345

# %%
plt.figure(figsize=(12, 9))
plt.scatter(df.index, df['prediction'], marker='x', color='r')
plt.scatter(df.index, df['actual'], alpha=0.3, marker='o', color='black')
plt.title("Prediction Result in Test Set", fontsize=20)
plt.legend(['prediction', 'actual'], fontsize=12)
plt.show()

# %%
### R square
print(model.score(X_train, y_train))  # training set
print(model.score(X_test, y_test))  # test set
# Out:
# 0.06595874096017884
# -0.08115554063239361

# %%
# RMSE
from sklearn.metrics import mean_squared_error
from math import sqrt

# training set
pred_train = lr.predict(X_train)
print(sqrt(mean_squared_error(y_train, pred_train)))

# test set
print(sqrt(mean_squared_error(y_test, pred_test)))
# Out:
# 2510.00956205439
# 2397.3421387853195
